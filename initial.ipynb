# %% [markdown]
# ### Load data frame

# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv("data/data_stations/TG_STAID000001.txt",skiprows=20,parse_dates=["    DATE"])

# %% [markdown]
# ### Simple statistics & data cleaning insights

# %%
df["   TG"].mean()
# Out:
# -991.1500649011311

# %%
df.loc[df["   TG"] != -9999]["   TG"].mean() / 10
# Out:
# 6.360787526128467

# %%
df.loc[df["   TG"] != -9999]["   TG"].max() / 10
# Out:
# 26.2

# %%
df.loc[df["   TG"] != -9999]["   TG"].min() / 10
# Out:
# -28.8

# %%
df.loc[df["   TG"] != -9999]["   TG"].mean()
# Out:
# 63.607875261284676

# %%
df.loc[df["    DATE"]=="1860-01-05"]["   TG"].squeeze() / 10
# Out:
# 3.1

# %%
df.loc[df["    DATE"]=="1860-01-05"]["    DATE"].squeeze()
# Out:
# Timestamp('1860-01-05 00:00:00')

# %% [markdown]
# ### Create and Calculate for a new column

# %%
import numpy as np
df["TG0"] = df["   TG"].mask(df["   TG"]==-9999,np.nan)


df["TG"] = df["TG0"] / 10

df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG0   TG
# 0          1   35381 1860-01-01     21      0  21.0  2.1
# 1          1   35381 1860-01-02     46      0  46.0  4.6
# 2          1   35381 1860-01-03     31      0  31.0  3.1
# 3          1   35381 1860-01-04     37      0  37.0  3.7
# 4          1   35381 1860-01-05     31      0  31.0  3.1
# ...      ...     ...        ...    ...    ...   ...  ...
# 59316      1   35381 2022-05-27  -9999      9   NaN  NaN
# 59317      1   35381 2022-05-28  -9999      9   NaN  NaN
# 59318      1   35381 2022-05-29  -9999      9   NaN  NaN
# 59319      1   35381 2022-05-30  -9999      9   NaN  NaN
# 59320      1   35381 2022-05-31  -9999      9   NaN  NaN
#
# [59321 rows x 7 columns]

# %%
df["TG0"].hist()
# Out:
# <AxesSubplot:>

# %%
df.plot(x="    DATE",y="TG",figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='    DATE'>
